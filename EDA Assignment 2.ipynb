# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # Flite Price

# %%
# Q.1
flite = pd.read_excel('flight_price.xlsx')
flite.shape
# Out:
# (10683, 11)

# %% [markdown]
# This dataset has 10683 rows and 11 columns

# %%
#Q.2
dis = flite.describe()
sns.histplot(dis)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
# Q.3

flite['Price'].min()
flite['Price'].max()
# Out:
# 79512

# %% [markdown]
# The price lie in range of 1759 - 79512
#
# The minimum price is 1759
#
# The maxmum price is 79512

# %%
# Q.4

sns.boxplot(data = flite,x='Price',y='Airline')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %%
# Q.5

sns.boxplot(flite)
# Out:
# <AxesSubplot: >

# %% [markdown]
# There are many outliers in this dataset
#
# The outliers can effect the skewness of data

# %% [markdown]
# # Q.6

# %%
flite['Date_of_Journey'].value_counts().sort_values(ascending = False)
# Out:
# 18/05/2019    504
# 6/06/2019     503
# 21/05/2019    497
# 9/06/2019     495
# 12/06/2019    493
# 9/05/2019     484
# 21/03/2019    423
# 15/05/2019    405
# 27/05/2019    382
# 27/06/2019    355
# 24/06/2019    351
# 1/06/2019     342
# 3/06/2019     333
# 15/06/2019    328
# 24/03/2019    323
# 6/03/2019     308
# 27/03/2019    299
# 24/05/2019    286
# 6/05/2019     282
# 1/05/2019     277
# 12/05/2019    259
# 1/04/2019     257
# 3/03/2019     218
# 9/03/2019     200
# 15/03/2019    162
# 18/03/2019    156
# 01/03/2019    152
# 12/03/2019    142
# 9/04/2019     125
# 3/04/2019     110
# 21/06/2019    109
# 18/06/2019    105
# 09/03/2019    102
# 6/04/2019     100
# 03/03/2019     97
# 06/03/2019     95
# 27/04/2019     94
# 24/04/2019     92
# 3/05/2019      90
# 15/04/2019     89
# 21/04/2019     82
# 18/04/2019     67
# 12/04/2019     63
# 1/03/2019      47
# Name: Date_of_Journey, dtype: int64

# %%
month = pd.to_datetime(flite['Date_of_Journey']).dt.month
season = pd.to_datetime(flite['Date_of_Journey']).dt.month.value_counts().sort_values(ascending = False)
# Out:
# /tmp/ipykernel_455/2920153685.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   month = pd.to_datetime(flite['Date_of_Journey']).dt.month
# /tmp/ipykernel_455/2920153685.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   season = pd.to_datetime(flite['Date_of_Journey']).dt.month.value_counts().sort_values(ascending = False)

# %%
season
# Out:
# 6     2536
# 3     2211
# 5     2074
# 9     1406
# 1     1075
# 12     957
# 4      424
# Name: Date_of_Journey, dtype: int64

# %% [markdown]
# The peak season is june in which most airline fly
#
# I used Data_of_Journey to analysis

# %% [markdown]
# # Q.7

# %%
flite
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
flite['Airline'].value_counts().sort_values(ascending = False)
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %% [markdown]
# The most used Aurline compeny is Jet Airways
#
# Most Travelling season is June

# %%
flite['Source'].value_counts().sort_values(ascending = False)
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %% [markdown]
# The most of the travellers are from Dehli

# %%
flite['Destination'].value_counts().sort_values(ascending  = False)
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %% [markdown]
# most of the people like to Cochine

# %% [markdown]
# #### Trend is that
#
# #### Most of the people went to Cochine from Delhi in the month of june by Jet Airline

# %%
flite
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# # Google playstore Data

# %%
# Q.9
gp = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
gp.shape
# Out:
# (10841, 13)

# %% [markdown]
# This dataset has 10841 rows and 13 columns

# %% [markdown]
# ### Q.10

# %%
gp.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
bx = gp[['Category','Rating']]
sns.boxplot(bx)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Q.11

# %%
gp.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# yes there are 1474 values missing in Rating column and 1 value in Type and content Rating and 8 values in current ver and 3  values missing in Android ver.Total 1487 values are missing in the dataset.
# Missing values can effect the modal training in machine learning

# %% [markdown]
# ## Q.12

# %%
sns.scatterplot(data = gp,x='Size',y = 'Rating',c='r')
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Rating'>

# %% [markdown]
# ## Q.13

# %%
gp['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '0.0', '1.20', '1.04'], dtype=object)

# %%
gp[['App','Price']]
# Out:
#                                                      App Price
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     0
# 1                                    Coloring book moana     0
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     0
# 3                                  Sketch - Draw & Paint     0
# 4                  Pixel Draw - Number Art Coloring Book     0
# ...                                                  ...   ...
# 10836                                   Sya9a Maroc - FR     0
# 10837                   Fr. Mike Schmitz Audio Teachings     0
# 10838                             Parkinson Exercices FR     0
# 10839                      The SCP Foundation DB fr nn5n     0
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     0
#
# [10841 rows x 2 columns]

# %%
gp['Price'] = gp['Price'].str.replace('$','').str.replace('Everyone','0.0')
# Out:
# /tmp/ipykernel_455/2021310413.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   gp['Price'] = gp['Price'].str.replace('$','').str.replace('Everyone','0.0')

# %%
gp['Price'] = gp['Price'].astype('float')

# %% [markdown]
# # Q.14

# %%
gp['App'].value_counts().sort_values(ascending=False).head(10)
# Out:
# ROBLOX                                               9
# CBS Sports App - Scores, News, Stats & Watch Live    8
# ESPN                                                 7
# Duolingo: Learn Languages Free                       7
# Candy Crush Saga                                     7
# 8 Ball Pool                                          7
# Subway Surfers                                       6
# Sniper 3D Gun Shooter: Free Shooting Games - FPS     6
# Helix Jump                                           6
# Temple Run 2                                         6
# Name: App, dtype: int64

# %%
gp[['App','Installs']].value_counts().sort_values(ascending=False).head(10)
# Out:
# App                                                 Installs
# ROBLOX                                              100,000,000+    9
# CBS Sports App - Scores, News, Stats & Watch Live   5,000,000+      8
# Duolingo: Learn Languages Free                      100,000,000+    7
# Candy Crush Saga                                    500,000,000+    7
# 8 Ball Pool                                         100,000,000+    7
# ESPN                                                10,000,000+     7
# Sniper 3D Gun Shooter: Free Shooting Games - FPS    100,000,000+    6
# Bleacher Report: sports news, scores, & highlights  5,000,000+      6
# Temple Run 2                                        500,000,000+    6
# Nick                                                10,000,000+     6
# dtype: int64

# %% [markdown]
# these are the most popular apps with their installation

# %% [markdown]
# ## Q.15

# %%
gp[['Category','Installs']].value_counts().sort_values(ascending = False)
# Out:
# Category            Installs
# FAMILY              1,000,000+     275
#                     100,000+       256
#                     10,000+        231
# GAME                10,000,000+    225
# FAMILY              1,000+         215
#                                   ...
# HOUSE_AND_HOME      10+              1
# PARENTING           10+              1
# HOUSE_AND_HOME      50+              1
# LIBRARIES_AND_DEMO  10+              1
# 1.9                 Free             1
# Length: 516, dtype: int64

# %% [markdown]
# The most popular categories are Family,Game

# %% [markdown]
# ## Q.16

# %%
gp.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159   19M      10,000+  Free    0.0       Everyone
# 1     967   14M     500,000+  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644   25M  50,000,000+  Free    0.0           Teen
# 4     967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...
